# %% [markdown]
# ## Figure downsampling

# %%
#| label: figDownsamplingX

import numpy as np
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.io as pio
from scipy.io import loadmat

# Interactive display in the notebook
pio.renderers.default = "plotly_mimetype"

# Check if static image export is available for PDF
try:
    pio.to_image(go.Figure(), format="png")
    static_export = True
except Exception as exc:
    static_export = False
    print(f"Static PNG export unavailable: {type(exc).__name__}: {exc}")

#K-spaces and image spaces downsampled by half according to x
data = loadmat("kx.mat")
kx = data["magx"]

data = loadmat("magimx.mat")
magimx = data["magimx"]

fig1 = make_subplots(1, 2, subplot_titles=("Downsampled k-space accoridng to X", "Reconstructed image"))

fig1.add_trace(go.Heatmap(visible=True, z=kx[:,:]), row=1, col=1)
fig1.add_trace(go.Heatmap(visible=True, z=magimx[:,:]), row=1, col=2)

'''DEFAULT = 0
fig.data[0].visible = True
fig.data[1].visible = True'''

fig1

# %%
#| label: figDownsamplingY

# Interactive display in the notebook
pio.renderers.default = "plotly_mimetype"

# Check if static image export is available for PDF
try:
    pio.to_image(go.Figure(), format="png")
    static_export = True
except Exception as exc:
    static_export = False
    print(f"Static PNG export unavailable: {type(exc).__name__}: {exc}")

#K-spaces and image spaces downsampled by half according to y
data = loadmat("ky.mat")
ky = data["magy"]

data = loadmat("magimy.mat")
magimy = data["magimy"]

fig2 = make_subplots(1, 2, subplot_titles=("Downsampled k-space accoridng to Y", "Reconstructed image"))

fig2.add_trace(go.Heatmap(visible=True, z=ky[:,:]), row=1, col=1)
fig2.add_trace(go.Heatmap(visible=True, z=magimy[:,:]), row=1, col=2)

'''DEFAULT = 0
fig.data[0].visible = True
fig.data[1].visible = True'''

fig2
